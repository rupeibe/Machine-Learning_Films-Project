# %% [markdown]
# ### Quiero poder predecir mediante un modelo de Machine Learning la puntuación de una película. Me quiero basar en las puntuaciones de películas de la web Filmaffinity. Por lo que recopilaré buna parte de las películas de la web, teniendo en cuenta que tengan más de 500 votos, no sean telefilmes ni películas de animación.

# %% [markdown]
# Importo las librerías necesarias

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup as bs
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
import requests
import time

# %% [markdown]
# Conecto mediante Selenium con la URL principal (listado de todas las películas) donde voy a conseguir las URLs de la ficha de cada película y obtener los datos como: nombre, año, director, actores, puntuación, etc...

# %%
# Conectamos con la web y abrimos ventana navegador en blanco
service = Service(executable_path=ChromeDriverManager().install())
driver = webdriver.Chrome(service=service)

# Conectamos con la web de Filmaffinity
driver.get("https://www.filmaffinity.com/es/topgen.php?genres=&chv=0&movietype=movie%7Cex-anim%3Aex-tv&country=&fromyear=1874&toyear=2023&ratingcount=2&runtimemin=0&runtimemax=4")

# Clickamos el botón de aceptar cookies
Cookies = driver.find_element(by="xpath", value="/html/body/div[1]/div/div/div/div[2]/div/button[2]/span")
Cookies.click()

# %% [markdown]
# Creo un buccle para caragar todos los registros completos y poder acceder a las URLs de las fichas de las películas

# %%
# Creamos un bucle para hacer scroll y cargar los resultados de todas las peliculas

for _ in range(750):
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(1)
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(1)
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(1)
    Bajar = driver.find_element(by = By.XPATH, value="/html/body/div[5]/table/tbody/tr/td[2]/div[1]/div[4]/div[5]/div/i")
    Bajar.click()

# %% [markdown]
# Mediante Beautiful Soup accedo al contenido de la web y extraigo (posición de la película en la lista, nombre y URL de la ficha de la película)

# %%
soup = bs(driver.page_source,"lxml")
info_peliculas = soup.select("div.mc-info-container")

# %%
posiciones = soup.select("li.position")
enlace_pelicula = soup.select("div.mc-title")[0].find("a")["href"]
nombre_pelicula = soup.select("div.mc-title")[0].find("a")["title"].strip()

# %%
posicion_pelicula = [posicion.get_text() for posicion in posiciones]
enlaces_peliculas = [enlace.select("div.mc-title")[0].find("a")["href"] for enlace in info_peliculas]
nombres_peliculas = [nombre.select("div.mc-title")[0].find("a")["title"].strip() for nombre in info_peliculas]

# %% [markdown]
# Logro una listado de 15850 URLs de películas

# %%
len(nombres_peliculas)
# Out:
# 15850

# %% [markdown]
# Convierto el diccionario donde tengo los datos en un dataframe

# %%
columnas = ["posicion", "pelicula", "enlace"]
datos = [posicion_pelicula, nombres_peliculas, enlaces_peliculas]

peliculas_enlaces_15850 = {col:dat for col, dat in zip(columnas, datos)}
df_pelis_enlaces_15850 = pd.DataFrame(peliculas_enlaces_15850)

# %% [markdown]
# Exporto dicho dataframe a un fichero CSV

# %%
# df_pelis_enlaces_15850.to_csv("..\data\raw\15850_mejores_peliculas_FilmAffinity_enlaces.csv", encoding= "utf16", index=False)

# %% [markdown]
# Leo ese CSV para poder accder a cada URL y extraer la información de cada película

# %%
df_pelis_enlaces = pd.read_csv(r"..\data\raw\15850_mejores_peliculas_FilmAffinity_enlaces.csv", encoding= "utf16", index_col=0)

# %% [markdown]
# Porciono el dataset en subsets para ir extrayendo la información más facilmente y no tardar tanto en cada proceso de extracción de información

# %%
df_pelis_enlaces_001 = df_pelis_enlaces.iloc[:1585,:]
df_pelis_enlaces_002 = df_pelis_enlaces.iloc[1585:3170,:]
df_pelis_enlaces_003 = df_pelis_enlaces.iloc[3170:4755,:]
df_pelis_enlaces_004 = df_pelis_enlaces.iloc[4755:6340,:]
df_pelis_enlaces_005 = df_pelis_enlaces.iloc[6340:9510,:]
df_pelis_enlaces_006 = df_pelis_enlaces.iloc[9510:11095,:]
df_pelis_enlaces_007 = df_pelis_enlaces.iloc[11095:12680,:]
df_pelis_enlaces_008 = df_pelis_enlaces.iloc[12680:14265,:]
df_pelis_enlaces_009 = df_pelis_enlaces.iloc[14265:,:]

# %%
response = requests.get("https://www.filmaffinity.com/es/main.html")
session = requests.Session()
session.close()

# %% [markdown]
# Creo un diccionario donde iré reuniendo la información que vaya extrayendo de la web

# %%
dicc_peliculas = {
                    "titulo_castellano": [],
                    "titulo_original": [],
                    "year": [],
                    "duracion": [],
                    "pais": [],
                    "director": [],
                    "guion": [],
                    "musica": [],
                    "fotografia": [],
                    "productora" : [],
                    "genero": [],
                    "actores": [],
                    "sinopsis": [],
                    "tags": [],
                    "votos": [],
                    "reviews":[],
                    "puntuacion" : []
                   }

# %% [markdown]
# Creo una función que se encargará de automatizar el proceso de recopilación de datos

# %%
def get_data(dataframe):
        
        for url in dataframe["enlace"]:
            
            try:
                 
                response = requests.get(url)
                session = requests.Session()
                html = response.content
                sopa = bs(html, "lxml")

                dicc_peliculas["titulo_castellano"].append(sopa.find_all("span", {"itemprop": "name"})[0].get_text().strip())
                dicc_peliculas["titulo_original"].append(sopa.find_all("dl", {"class": "movie-info"})[0].find("dd").get_text().replace("\n","").strip())
                dicc_peliculas["year"].append(sopa.find_all("dd", {"itemprop": "datePublished"})[0].get_text())
                dicc_peliculas["duracion"].append(sopa.find_all("dd", {"itemprop": "duration"})[0].get_text().split()[0])
                dicc_peliculas["pais"].append(sopa.find_all("span", {"id": "country-img"})[0].find("img")["alt"])
                dicc_peliculas["director"].append(sopa.find_all("span", {"itemprop": "name"})[1].get_text())
                dicc_peliculas["guion"].append(sopa.find_all("div", {"class": "credits"})[1].find_all("span",{"class":"nb"})[0].find("span").get_text())
                dicc_peliculas["musica"].append(sopa.find_all("div", {"class": "credits"})[2].find("span").find("span").get_text())

                dicc_peliculas["fotografia"].append(sopa.find_all("div", {"class": "credits"})[3].find("span").find("span").get_text())
                dicc_peliculas["productora"].append(soup.find_all("dd", {"class":"card-producer"})[0].find("span").find("span").get_text().strip())             
                dicc_peliculas["genero"].append(sopa.find_all("span", {"itemprop": "genre"})[0].get_text())

                reparto = sopa.find_all("a", {"itemprop": "url"})[1:6]
                actores = []
                for actor in reparto:
                    actores.append(actor["title"])
                dicc_peliculas["actores"].append(actores)

                dicc_peliculas["sinopsis"].append(sopa.find('dd', itemprop='description').get_text())

                etiquetas = sopa.find_all("dd", {"class": "card-genres"})[0].find_all("a")
                tags = []
                for etiqueta in etiquetas:
                    tags.append(etiqueta.get_text())
                dicc_peliculas["tags"].append(tags)
                
                dicc_peliculas["votos"].append(sopa.find_all("div", {"id": "movie-count-rat"})[0].get_text().replace("\n","").replace(".","").split("votos")[0])
                dicc_peliculas["reviews"].append(sopa.find_all("div", {"id": "movie-reviews-box"})[0].get_text().replace("\n","").replace(" ","").split("críticas")[0])
                dicc_peliculas["puntuacion"].append(sopa.find_all("div", {"id": "movie-rat-avg"})[0].get_text().strip())
                
            except:
                pass
        session.close()        
        return dicc_peliculas

# %%
len(df_pelis_enlaces_005)
# Out:
# 3170

# %%
get_data(df_pelis_enlaces_005)

# %% [markdown]
# Me aseguro que cada clave del diccionario tienen la misma longitud para así poder crear el dataframe con todos los registros

# %%
for key, value in dicc_peliculas.items():
    print(key, len(value))

# %% [markdown]
# Exporto los registros obtenidos a un fichero CSV para poder posteriormente continuar con el proceso de limpieza y análisis de los datos

# %%
# df_peliculas_005 = pd.DataFrame(dicc_peliculas)
# df_peliculas_005.to_csv("..\data\raw\fichas_peliculas\pelis_005.csv", encoding= "utf16", index= False)

# %% [markdown]
# ### Para que el algoritmo tenga mayor información para predecir quiero integrar en los datos los principales premios que pueden recibir las películas.

# %% [markdown]
# Primero obtengo los enlaces de todos los festivales de cine y premios de academias de cine de todos los paises

# %%
response = requests.get("https://www.filmaffinity.com/es/all_awards.php")
html = response.content
sopa = bs(html, "lxml")

enlaces = sopa.find_all("div",{"class":"award-container"})
enlaces_festivales_lista = []
for award in enlaces:
    a_tag = award.find("a")
    if a_tag is not None:
        enlaces_festivales_lista.append(award.find("a")["href"])
    else:
        enlaces_festivales_lista.append("Link not found")

# %% [markdown]
# Obtengo de cada URL de cada festival de cine las URL de las 2 categorías principales, que corresponden a películas

# %%
categorias_festivales_lista = []
for url in enlaces_festivales_lista:

  url_001 = url.split("=")[1]
  new_url = url[:37]+"-edition.php?edition-id="+url_001+"_2022"

  response = requests.get(new_url)
  html = response.content
  sopa = bs(html, "lxml")
  
  categorias_awards = sopa.find_all("div", {"class":"vwacat"})
  
  for categoria in categorias_awards:
    categorias_festivales_lista.append(categoria.find("a")["href"])

# %% [markdown]
# Guardo los resultados en un dataframe

# %%
df_festivales_awards = pd.DataFrame(categorias_festivales_lista)

# %%
# df_festivales_awards.to_csv(r"..\data\raw\enlaces_todas_categorias_todos_festivales.csv", encoding="utf16", index = False)

# %% [markdown]
# Guardo el dataframe en un csv para poder importarlo después

# %%
df_festivales_awards = pd.read_csvr(r"..\data\raw\enlaces_todas_categorias_todos_festivales.csv", encoding= "utf16", index_col=0)

# %%
list_definitive = list(df_festivales_awards["0"])

# %% [markdown]
# Obtengo una lista de los enlaces de todas las categorías de cada festival para acceder al histórico de películas de todos las años

# %% [markdown]
# Premios Razzie

# %%
peliculas_festivales_lista = []
dicc_peliculas_certamenes = {}
categorias_festivales_lista =[]

response = requests.get("https://www.filmaffinity.com/es/award-edition.php?edition-id=razzie_2022")
html = response.content
sopa = bs(html, "lxml")

categorias_awards = sopa.find_all("div", {"class":"vwacat"})

for categoria in categorias_awards:
    categorias_festivales_lista.append(categoria.find("a")["href"])

# %%
for url in categorias_festivales_lista:
    pelis_por_premio = []
    nombre_festivales_lista = []    
    categoria_festivales_lista = []

    response = requests.get(url)
    html = response.content
    sopa = bs(html, "lxml")

    datos_pelicula = sopa.find_all("span", {"class":"movie-title-link"})
    datos_director = sopa.find_all("span", {"class":"nb"})
    datos_year = sopa.find_all("div", {"class":"year"})

    festival = sopa.find_all("h1")[0].get_text().split("-",1)[0].strip()
    categoria = sopa.find_all("h1")[0].get_text().split("-",1)[1].split("Todos los ganadores")[0].strip()

    for pelicula, director, year  in zip(datos_pelicula, datos_director, datos_year):
        pelicula = pelicula.find("a").get_text().strip()
        director = director.find("a").get_text().replace('"',"").strip()
        years = year.find("a").get_text().strip()
        peliculas_festivales_lista.append(f"{festival} @ {categoria} @ {years} @ {pelicula} @ {director}")

# %%
dicc_peliculas_certamenes["premios_peliculas"] = peliculas_festivales_lista
df_premios_peliculas = pd.DataFrame(dicc_peliculas_certamenes)
# df_premios_peliculas.to_csv(r"..\data\raw\peliculas_razzie.csv", encoding="utf16")

# %%
reparto_festivales_lista = []
dicc_reparto_certamenes = {}

for url in categorias_festivales_lista:

    pelis_por_premio = []
    nombre_festivales_lista = []    
    categoria_festivales_lista = []

    response = requests.get(url)
    html = response.content
    sopa = bs(html, "lxml")

    datos_reparto = sopa.find_all("div", {"class":"nom-text"})
    datos_pelicula = sopa.find_all("span", {"class":"movie-title-link"})
    datos_director = sopa.find_all("div", {"class":"credits"})
    datos_year = sopa.find_all("div", {"class":"year"})

    festival = sopa.find_all("h1")[0].get_text().split("-",1)[0].strip()
    categoria = sopa.find_all("h1")[0].get_text().split("-",1)[1].split("Todos los ganadores")[0].strip()
    
    for reparto, pelicula, director, year  in zip(datos_reparto, datos_pelicula, datos_director, datos_year):
        reparto = reparto.get_text().strip()
        pelicula = pelicula.find("a").get_text().strip()
        director = director.find("a").get_text().replace('"',"").strip()
        years = year.find("a").get_text().strip()
        reparto_festivales_lista.append(f"{festival} @ {categoria} @ {years} @ {reparto} @ {pelicula} @ {director}")

# %%
dicc_reparto_certamenes["premios_reparto"] = reparto_festivales_lista
df_premios_reparto = pd.DataFrame(dicc_reparto_certamenes)
# df_premios_reparto.to_csv("..\data\raw\reparto_razzie.csv", encoding="utf16")

# %%
list_definitive
# Out:
# ['https://www.filmaffinity.com/es/awards-history.php?cat-id=cannes_golden_palm',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=cannes_grand_prix',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=cannes_best_director',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=cannes_best_actor',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=cannes_best_actress',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=cannes_best_screenplay',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=cannes_fipresci',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=cannes_camera_d_or',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=cannes_jury_prize',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=cannes_best_short_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=cannes_un_certain_regard_best_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=cannes_un_certain_regard_jury_prize',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=cannes_un_certain_regard_directing_prize',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=cannes_un_certain_regard_screenplay',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=cannes_un_certain_regard_best_performance',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=cannes_un_certain_regard_jurys_coup_de_coeur',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=cannes_75anniversary',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=berlin_golden_bear',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=berlin_jury_grand_prix',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=berlin_best_director',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=berlin_best_leading_performance',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=berlin_best_supporting_performance',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=berlin_best_screenplay',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=berlin_jury_prize',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=berlin_art_contribution',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=berlin_fipresci',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=berlin_special_mention',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=berlin_generation_kplus_crystal_bear',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=berlin_international_best_short_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=berlin_short_film_jury_prize',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=berlin_short_film_special_mention',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=berlin_best_documentary',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=berlin_documentary_special_mention',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=venice_golden_lion',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=venice_grand_jury_prize',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=venice_silver_lion',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=venice_special_jury_prize',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=venice_best_actress',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=venice_best_actor',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=venice_best_screenplay',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=venice_best_new_young_actor',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=venice_fipresci',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=venice_orizzonti_best_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=venice_best_first_work',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=ss_concha_oro',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=ss_premio_esp_jurado',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=ss_mejor_director',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=ss_mejor_interprete',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=ss_mejor_interpretacion_reparto',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=ss_mejor_guion',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=ss_mejor_fotografia',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=ss_audience_award',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=ss_audience_award_european',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=ss_fipresci',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=ss_premio_horizontes',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=ss_nuevos_realizadores',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=ss_youth_award',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=ss_signis_award',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=ss_premio_cooperacion',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=ss_premio_otra_mirada',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=ss_premio_cine_vasco',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=ss_feroz_zinemaldia',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=ss_donostia_award',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=toronto_choice_award',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=toronto_choice_award_doc',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=toronto_best_canadian_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=toronto_choice_award_mad',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=toronto_discovery_award',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=toronto_netpac_award',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=annecy_best_feature',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=annecy_special_distinction',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=annecy_best_film_contrechamp',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=annecy_annecy_cristal_best_short_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=annecy_special_jury_award',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=annecy_best_first_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=annecy_best_music',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=annecy_off-limits_award',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=annecy_best_tv_production',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=gijon_mejor_pelicula_retueyos',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=gijon_mejor_pelicula_albar',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=gijon_mejor_pelicula_trance',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=gijon_mejor_director',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=gijon_mejor_actor',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=gijon_mejor_actriz',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=gijon_premio_distribucion',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=gijon_young_jury_prize_best_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=gijon_audience_award',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=gijon_best_short',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=locarno_best_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=locarno_special_jury_prize',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=locarno_best_director',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=locarno_best_actor',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=locarno_best_actress',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=locarno_cineasti_del_presente_best_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=locarno_cineasti_del_presente_special_jury_prize',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=locarno_cineasti_del_presente_emerging_director',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=locarno_cineasti_del_presente_best_actress',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=locarno_cineasti_del_presente_best_actor',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=locarno_cineasti_del_presente_special_mention',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=locarno_best_first_feature',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=locarno_best_first_feature_mention',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sundance_grand_jury_drama',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sundance_grand_jury_documentary',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sundance_grand_jury_world_dramatic',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sundance_grand_jury_world_doc',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sundance_best_ensemble',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sundance_audience_dramatic',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sundance_audience_documentary',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sundance_world_audience_dramatic',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sundance_world_audience_doc',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sundance_directing_award_dramatic',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sundance_directing_award_documentary',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sundance_directing_world_dramatic',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sundance_directing_world_documentary',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sundance_screenwriting_award',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sundance_documentary_editing',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sundance_special_jury_world_dramatic',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sundance_special_jury_world_doc',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sundance_special_jury_dramatic',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sundance_special_jury_documentary',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sundance_short_film_grand_jury',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=tribeca_best_us_narrative_feature',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=tribeca_best_screenplay_us',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=tribeca_best_cinematography_us',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=tribeca_special_jury_mention',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=tribeca_best_performance',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=tribeca_best_new_director',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=tribeca_best_international_narrative_feature',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=tribeca_best_screenplay_international',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=tribeca_best_cinematography_international',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=tribeca_best_performance_international',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=tribeca_best_documentary_feature',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=tribeca_best_new_documentary_director',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=tribeca_best_cinematography_doc',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=tribeca_best_editing_doc',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=tribeca_audience_award',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=seminci_best_picture',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=seminci_silver_spike',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=seminci_best_director',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=seminci_best_actor',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=seminci_best_actress',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=seminci_best_new_director',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=seminci_best_script',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=seminci_best_cinematographer',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=seminci_best_editing',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=seminci_fipresci',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=seminci_best_short_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=seminci_silver_spike_short_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=seminci_audience_award',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=seminci_best_iberoamerican_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=seminci_young_seminci',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=mar_best_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=mar_special_jury_award',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=mar_special_mention',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=mar_best_director',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=mar_best_performance',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=mar_best_screenplay',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=mar_best_iberoamerican',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=mar_iberoamerican_mention',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=mar_iberoamerican_special_jury_award',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=mar_best_argentinian_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=mar_best_argentinian_director',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=mar_best_short_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=mar_best_argentinian_short_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=malaga_best_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=malaga_special_jury_prize',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=malaga_best_latin_american_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=malaga_best_direction',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=malaga_best_actor',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=malaga_best_actress',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=malaga_best_supporting_actor',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=malaga_best_supporting_actress',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=malaga_best_screenplay',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=malaga_best_soundtrack',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=malaga_best_cinematography',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=malaga_best_editing',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=malaga_special_mention_jury',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=malaga_audience_award_documentary',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=malaga_feroz_award',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sitges_best_picture',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sitges_special_jury_award',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sitges_best_director',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sitges_best_actor',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sitges_best_actress',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sitges_best_screenplay',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sitges_best_cinematography',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sitges_best_special_effects',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sitges_best_ost',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sitges_audience_award',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sitges_fipresci',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sitges_best_film_panorama',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sitges_best_animated_feature',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sitges_best_short_film_animated',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sitges_best_short_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sitges_best_film_focus_asia',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sitges_best_film_novesvisions',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sitges_best_director_novesvisions',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sitges_best_short_film_novesvisions',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sitges_best_film_midnight',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sitges_best_film_orbita',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sitges_best_film_blood_window',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sitges_best_film_silver_melies',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sitges_best_short_film_silver_melies',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sitges_best_short_film_brigadoon',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sitges_sgae_nova_autoria_best_direction',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sitges_sgae_nova_autoria_best_screenplay',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sitges_sgae_nova_autoria_best_music',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sitges_best_film_jove_juryaward',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sitges_maquina_del_tiempo',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sevilla_best_gold_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sevilla_special_jury_prize',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sevilla_best_direction',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sevilla_best_actor',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sevilla_best_actress',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sevilla_best_screenplay',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sevilla_best_cinematography',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sevilla_best_editing',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sevilla_audience_award',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=rotterdam_best_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=rotterdam_special_jury_award',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=rotterdam_fipresci',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=tokyo_best_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=tokyo_special_jury_prize',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=tokyo_best_director',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=tokyo_best_actor',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=tokyo_best_actress',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=tokyo_audience_award',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=tokyo_best_artistic_contribution',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=academy_awards_best_picture',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=academy_awards_best_director',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=academy_awards_best_leading_actress',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=academy_awards_best_leading_actor',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=academy_awards_best_supporting_actor',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=academy_awards_best_supporting_actress',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=academy_awards_best_foreign_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=academy_awards_best_original_screenplay',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=academy_awards_best_adapted_screenplay',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=academy_awards_best_editing',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=academy_awards_best_cinematography',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=academy_awards_best_score',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=academy_awards_best_song',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=academy_awards_best_art_direction',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=academy_awards_best_costume_design',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=academy_awards_best_makeup',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=academy_awards_best_sound_mixing',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=academy_awards_best_visual_effects',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=academy_awards_best_animated_feature',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=academy_awards_best_short_film_animated',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=academy_awards_best_documentary_feature',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=academy_awards_best_short_film_documentary',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=academy_awards_best_short_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=academy_awards_honorary_award',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=goldenglobes_best_picture_drama',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=goldenglobes_best_picture_comedy',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=goldenglobes_best_director',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=goldenglobes_best_leading_actor_drama',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=goldenglobes_best_leading_actress_drama',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=goldenglobes_best_leading_actor_comedy',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=goldenglobes_best_leading_actress_comedy',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=goldenglobes_best_supporting_actor',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=goldenglobes_best_supporting_actress',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=goldenglobes_best_screenplay',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=goldenglobes_best_original_score',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=goldenglobes_best_original_song',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=goldenglobes_best_foreign_language_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=goldenglobes_best_animated_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=goldenglobes_best_tv_series_drama',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=goldenglobes_best_tv_series_comedy',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=goldenglobes_best_leading_actor_tv_series_drama',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=goldenglobes_best_leading_actress_tv_series_drama',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=goldenglobes_best_leading_actor_tv_series_comedy',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=goldenglobes_best_leading_actress_tv_series_comedy',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=goldenglobes_best_miniseries_tv',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=goldenglobes_best_actor_miniseries_tv',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=goldenglobes_best_actress_miniseries_tv',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=goldenglobes_best_supporting_actor_series_tv',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=goldenglobes_best_supporting_actress_series_tv',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=goldenglobes_carol_burnett_award',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=goldenglobes_cecil_b_demille',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=emmy_drama_series',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=emmy_comedy_series',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=emmy_tv_movie',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=emmy_best_miniseries_tv_movie',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=emmy_lead_actor_drama_series',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=emmy_lead_actor_comedy_series',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=emmy_lead_actor_miniseries_tvmovie',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=emmy_lead_actress_drama_series',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=emmy_lead_actress_comedy_series',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=emmy_lead_actress_miniseries_tvmovie',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=emmy_supporting_actor_drama_series',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=emmy_supporting_actor_comedy_series',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=emmy_supporting_actor_miniseries_tvmovie',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=emmy_supporting_actress_drama_series',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=emmy_supporting_actress_comedy_series',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=emmy_supporting_actress_miniseries_tvmovie',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=emmy_guest_actor_drama',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=emmy_guest_actress_drama',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=emmy_guest_actor_comedy',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=emmy_guest_actress_comedy',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=emmy_directing_drama',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=emmy_directing_comedy',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=emmy_directing_miniseries_movie',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=emmy_writing_drama',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=emmy_writing_comedy',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=emmy_writing_miniseries_movie',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=emmy_animated_program',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=emmy_animated_program_short',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=emmy_outstanding_individual_achievement_animation',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=emmy_documentary_nonfiction_series',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=bafta_best_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=bafta_british_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=bafta_best_director',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=bafta_best_leading_actor',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=bafta_best_leading_actress',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=bafta_best_supporting_actor',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=bafta_best_supporting_actress',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=bafta_best_casting',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=bafta_most_outstanding_newcomer_to_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=bafta_best_original_screenplay',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=bafta_best_adapted_screenplay',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=bafta_best_cinematographer',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=bafta_best_editing',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=bafta_best_music',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=bafta_best_production_design',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=bafta_best_costume_design',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=bafta_best_makeup_hair',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=bafta_best_sound',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=bafta_best_visual_effects',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=bafta_best_foreign_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=bafta_best_animated_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=bafta_best_documentary',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=bafta_best_short',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=bafta_best_short_animation',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=bafta_best_british_debut',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=bafta_best_tv_drama',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=bafta_best_tv_situation_comedy',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=bafta_best_tv_international',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=bafta_best_tv_mini_series',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=bafta_best_single_drama',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=bafta_best_tv_soap',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=bafta_best_tv_director',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=bafta_best_actor_drama',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=bafta_best_actress_drama',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=bafta_best_sup_actor_drama',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=bafta_best_sup_actress_drama',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=bafta_best_actor_comedy',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=bafta_best_actress_comedy',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=bafta_best_scriptedy_casting',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=bafta_best_tv_screenplay',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=bafta_best_tv_screenplay_comedy',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=bafta_best_vtr_editor',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=bafta_best_tv_photography',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=bafta_best_original_television_music',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=bafta_best_tv_production_design',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=bafta_best_tv_costume',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=bafta_best_tv_makeup',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=bafta_best_tv_sound',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=bafta_best_visual_effects_tv',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=cesar_best_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=cesar_best_director',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=cesar_best_actor',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=cesar_best_actress',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=cesar_best_supporting_actor',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=cesar_best_supporting_actress',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=cesar_best_promising_actor',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=cesar_best_promising_actress',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=cesar_best_original_screenplay',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=cesar_best_adapted_screenplay',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=cesar_best_cinematography',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=cesar_best_editing',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=cesar_best_music',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=cesar_best_production_design',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=cesar_best_visual_effects',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=cesar_best_costume_design',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=cesar_best_sound',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=cesar_best_first_work',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=cesar_best_foreign_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=cesar_best_animated_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=cesar_best_documentary',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=cesar_best_short_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=cesar_best_animated_short_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=cesar_best_short_documentary',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=cesar_honorary_cesar',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=donatello_best_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=donatello_best_director',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=donatello_best_foreign_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=donatello_best_actor',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=donatello_best_actress',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=donatello_best_supporting_actor',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=donatello_best_supporting_actress',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=donatello_best_screenplay',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=donatello_best_adapted_screenplay',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=donatello_best_cinematography',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=donatello_best_editing',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=donatello_best_music',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=donatello_best_original_song',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=donatello_best_visual_effects',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=donatello_best_sound',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=donatello_best_costume_design',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=donatello_best_producer',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=donatello_best_make_up',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=donatello_best_production_design',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=donatello_best_hair_design',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=donatello_best_new_director',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=donatello_best_documentary',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=donatello_audience_award',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=donatello_best_short_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=goya_best_picture',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=goya_best_director',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=goya_best_leading_actor',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=goya_best_leading_actress',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=goya_best_supporting_actor',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=goya_best_supporting_actress',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=goya_best_new_director',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=goya_best_upcoming_actor',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=goya_best_upcoming_actress',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=goya_best_original_screenplay',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=goya_best_adapted_screenplay',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=goya_best_cinematography',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=goya_best_editing',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=goya_best_score',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=goya_best_song',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=goya_best_art_production',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=goya_best_art_direction',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=goya_best_costume_design',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=goya_best_makeup',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=goya_best_sound',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=goya_best_special_effects',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=goya_best_hispano_american_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=goya_best_european_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=goya_best_documentary',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=goya_best_animated_feature',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=goya_best_animated_short_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=goya_best_short_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=goya_best_documentary_short_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=goya_honorary_award',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=goya_international_award',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=guldbagge_best_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=guldbagge_best_direction',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=guldbagge_best_actress',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=guldbagge_best_actor',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=guldbagge_best_supporting_actress',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=guldbagge_best_supporting_actor',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=guldbagge_best_screenplay',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=guldbagge_best_cinematography',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=guldbagge_best_music',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=guldbagge_best_editing',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=guldbagge_best_costume',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=guldbagge_best_sound',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=guldbagge_best_makeup',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=guldbagge_best_set_design',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=guldbagge_best_visual_effects',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=guldbagge_best_documentary',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=guldbagge_best_foreign_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=guldbagge_best_short_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=guldbagge_honorary_award',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=german_best_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=german_first_runner_up',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=german_second_runner_up',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=german_best_director',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=german_best_actress',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=german_best_actor',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=german_best_supporting_actress',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=german_best_supporting_actor',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=german_best_screenplay',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=german_best_score',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=german_best_cinematography',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=german_best_editing',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=german_best_set_design',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=german_best_costume_design',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=german_best_make_up',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=german_best_sound_design',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=german_best_visual_effects',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=german_best_children_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=german_best_documentary',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=german_most_commercially_successful_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=german_honorary_award',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=canadian_best_picture',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=canadian_best_animated_short',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=canadian_best_video_game',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=ariel_best_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=ariel_best_director',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=ariel_best_leading_actor',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=ariel_best_leading_actress',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=ariel_best_supporting_actor',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=ariel_best_supporting_actress',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=ariel_best_upcoming_actor_or_actress',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=ariel_best_original_screenplay',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=ariel_best_adapted_screenplay',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=ariel_best_editing',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=ariel_best_cinematography',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=ariel_best_score',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=ariel_best_sound',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=ariel_best_art_direction',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=ariel_best_costume_design',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=ariel_best_makeup',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=ariel_best_visual_effects',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=ariel_best_special_effects',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=ariel_best_first_work',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=ariel_best_latin_american_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=ariel_best_animated_feature',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=ariel_best_documentary',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=ariel_best_short_animated',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=ariel_best_short_fiction',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=ariel_best_short_documentary',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=macondo_best_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=macondo_best_director',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=macondo_best_leading_actor',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=macondo_best_leading_actress',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=macondo_best_supporting_actor',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=macondo_best_supporting_actress',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=macondo_best_screenplay',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=macondo_best_cinematography',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=macondo_best_editing',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=macondo_best_art_direction',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=macondo_best_sound_design',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=macondo_best_costume_design',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=macondo_best_makeup',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=macondo_best_score',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=macondo_best_original_song',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=macondo_VFX_best_visual_effects',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=macondo_best_documentary',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=macondo_best_short_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=macondo_best_ibero_american_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=macondo_choice_award',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=annie_best_animated_feature',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=annie_best_animated_feature_independent',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=annie_directing_feature',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=annie_writing_feature',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=annie_storyboard_feature',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=annie_character_animation',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=annie_character_desing',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=annie_production_design_feature',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=annie_voice_acting_feature',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=annie_music_feature',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=annie_best_editing',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=annie_animated_effects',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=annie_best_animated_short',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=annie_best_animated_special_production',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=annie_best_animated_television_production',
# ...
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=platino_best_music',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=platino_mejor_fotografia',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=platino_mejor_montaje',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=platino_mejor_pelicula_animacion',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=platino_mejor_documental',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=platino_mejor_opera_prima',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=platino_mejor_sonido',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=platino_mejor_direccion_artistica',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=platino_mejor_miniserie',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=platino_mejor_actor_serie',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=platino_mejor_actriz_serie',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=platino_mejor_actor_reparto_serie',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=platino_mejor_actriz_reparto_serie',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=platino_mejor_creador',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=platino_premio_educacion_valores',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=european_best_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=european_best_director',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=european_best_actress',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=european_best_actor',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=european_best_screenplay',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=european_best_cinematographer',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=european_best_composer',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=european_best_editor',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=european_best_designer',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=european_best_costume',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=european_best_sound',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=european_best_make_up',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=european_best_visual_effects',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=european_best_animated',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=european_best_documentary',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=european_best_european_comedy',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=european_discovery_award',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=european_best_short_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=european_innovative_storytelling',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=european_european_university',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=european_honorary_award',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=nbr_best_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=nbr_top_ten_films',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=nbr_best_director',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=nbr_best_actor',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=nbr_best_actress',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=nbr_best_supporting_actor',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=nbr_best_supporting_actress',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=nbr_best_cast',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=nbr_breakthrough_actor',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=nbr_breakthrough_actress',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=nbr_best_directorial_debut',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=nbr_best_original_screenplay',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=nbr_best_adapted_screenplay',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=nbr_best_cinematography',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=nbr_best_animated_feature',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=nbr_best_foreign_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=nbr_top_five_foreign_films',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=nbr_best_documentary',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=nbr_top_five_documentaries',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=nbr_freedom_expression_award',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=nyfcc_best_picture',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=nyfcc_best_director',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=nyfcc_best_actor',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=nyfcc_best_actress',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=nyfcc_best_supporting_actor',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=nyfcc_best_supporting_actress',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=nyfcc_best_screenplay',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=nyfcc_best_cinematographer',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=nyfcc_best_foreign_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=nyfcc_best_animated_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=nyfcc_best_first_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=nyfcc_best_documentary',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=lafca_best_picture',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=lafca_best_director',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=lafca_best_lead_performance',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=lafca_best_supp_performance',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=lafca_best_screenplay',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=lafca_best_editing',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=lafca_best_cinematographer',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=lafca_best_production_design',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=lafca_best_score',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=lafca_best_foreign_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=lafca_best_animated_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=lafca_best_documentary',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=lafca_experimental_independent',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=critics_choice_awards_best_picture',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=critics_choice_awards_best_director',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=critics_choice_awards_best_actor',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=critics_choice_awards_best_actress',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=critics_choice_awards_best_supporting_actor',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=critics_choice_awards_best_supporting_actress',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=critics_choice_awards_breakthrough_actor',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=critics_choice_awards_best_cast',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=critics_choice_awards_best_original_screenplay',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=critics_choice_awards_best_adapted_screenplay',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=critics_choice_awards_best_cinematography',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=critics_choice_awards_best_art_direction',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=critics_choice_awards_best_editing',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=critics_choice_awards_best_visual_effects',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=critics_choice_awards_best_costume_design',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=critics_choice_awards_best_makeup',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=critics_choice_awards_best_score',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=critics_choice_awards_best_song',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=critics_choice_awards_best_animated_feature',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=critics_choice_awards_best_comedy',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=critics_choice_awards_best_foreign_language_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=critics_choice_awards_best_series_drama',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=critics_choice_awards_best_actor_series_drama',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=critics_choice_awards_best_actress_series_drama',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=critics_choice_awards_best_supp_actor_tv_drama',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=critics_choice_awards_best_supp_actress_tv_drama',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=critics_choice_awards_best_series_comedy',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=critics_choice_awards_best_actor_series_comedy',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=critics_choice_awards_best_actress_series_comedy',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=critics_choice_awards_best_supp_actor_tv_comedy',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=critics_choice_awards_best_supp_actress_tv_comedy',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=critics_choice_awards_best_limited_series',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=critics_choice_awards_best_tv_movie',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=critics_choice_awards_best_actor_tvmovie',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=critics_choice_awards_best_actress_tvmovie',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=critics_choice_awards_best_supp_actor_tvmovie',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=critics_choice_awards_best_supp_actress_tvmovie',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=critics_choice_awards_best_foreign_language_series',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=critics_choice_awards_best_animation_series',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=critics_choice_awards_best_comedy_special',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=cfca_best_picture',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=cfca_best_director',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=cfca_best_actor',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=cfca_best_actress',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=cfca_best_supporting_actor',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=cfca_best_supporting_actress',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=cfca_most_promising_performer',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=cfca_best_screenplay',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=cfca_best_adapted_screenplay',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=cfca_most_promising_filmmaker',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=cfca_best_score',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=cfca_Best_editing',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=cfca_best_cinematography',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=cfca_best_visual_effects',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=cfca_best_art_direction',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=cfca_best_costume_design',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=cfca_best_foreign_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=cfca_best_animated_feature',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=cfca_best_documentary',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=bsfc_best_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sag_best_cast_picture',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sag_best_actor_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sag_best_actress_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sag_best_supporting_actor_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sag_best_supporting_actress_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sag_best_cast_drama_series',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sag_best_cast_comedy_series',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sag_best_actor_drama_series',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sag_best_actress_drama_series',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sag_best_actor_comedy_series',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sag_best_actress_comedy_series',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sag_best_actor_miniseries',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sag_best_actress_miniseries',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sag_best_stunt_picture',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=sag_best_stunt_series',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=dga_feature_film',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=dga_documentary',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=dga_dramatic_series',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=dga_comedy_series',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=dga_tvmovie_miniseries',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=dga_breakthrough_director',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=wga_best_original_screenplay',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=wga_best_adapted_screenplay',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=wga_best_documentary_screenplay',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=wga_best_dramatic_series_screenplay',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=wga_best_comedy_series_screenplay',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=wga_best_new_series_screenplay',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=wga_best_tv_animation_screenplay',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=wga_best_long_form_original_screenplay',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=wga_best_long_form_adaptation_screenplay',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=wga_best_episodic_drama_screenplay',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=wga_best_episodic_comedy_screenplay',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=afi_best_movies',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=afi_best_tvshows',
#  'https://www.filmaffinity.com/es/awards-history.php?cat-id=afi_afi_special_award']

# %% [markdown]
# A partir de cada URL obtengo informacion del historio de peliculas (sólo peliculas) premiadas de todos los festivales

# %%
peliculas_festivales_lista = []
dicc_peliculas_certamenes = {}

for url in list_definitive:

    pelis_por_premio = []
    nombre_festivales_lista = []    
    categoria_festivales_lista = []

    response = requests.get(url)
    html = response.content
    sopa = bs(html, "lxml")

    datos_pelicula = sopa.find_all("span", {"class":"movie-title-link"})
    datos_director = sopa.find_all("span", {"class":"nb"})
    datos_year = sopa.find_all("div", {"class":"year"})

    festival = sopa.find_all("h1")[0].get_text().split("-",1)[0].strip()
    categoria = sopa.find_all("h1")[0].get_text().split("-",1)[1].split("Todos los ganadores")[0].strip()
    
    for pelicula, director, year  in zip(datos_pelicula, datos_director, datos_year):
        pelicula = pelicula.find("a").get_text().strip()
        director = director.find("a").get_text().replace('"',"").strip()
        years = year.find("a").get_text().strip()
        peliculas_festivales_lista.append(f"{festival} @ {categoria} @ {years} @ {pelicula} @ {director}")

# %%
dicc_peliculas_certamenes["premios_peliculas"] = peliculas_festivales_lista
df_premios_peliculas = pd.DataFrame(dicc_peliculas_certamenes)
# df_premios_peliculas.to_csv("..\data\processed\premios_peliculas.csv", encoding="utf16")

# %% [markdown]
# A partir de cada UL obtengo informacion del historio de peliculas (directores, actores) premiadas de todos los festivales

# %%
reparto_festivales_lista = []
dicc_reparto_certamenes = {}

for url in list_definitive:

    pelis_por_premio = []
    nombre_festivales_lista = []    
    categoria_festivales_lista = []

    response = requests.get(url)
    html = response.content
    sopa = bs(html, "lxml")

    datos_reparto = sopa.find_all("div", {"class":"nom-text"})
    datos_pelicula = sopa.find_all("span", {"class":"movie-title-link"})
    datos_director = sopa.find_all("div", {"class":"credits"})
    datos_year = sopa.find_all("div", {"class":"year"})

    festival = sopa.find_all("h1")[0].get_text().split("-",1)[0].strip()
    categoria = sopa.find_all("h1")[0].get_text().split("-",1)[1].split("Todos los ganadores")[0].strip()
    
    for reparto, pelicula, director, year  in zip(datos_reparto, datos_pelicula, datos_director, datos_year):
        reparto = reparto.get_text().strip()
        pelicula = pelicula.find("a").get_text().strip()
        director = director.find("a").get_text().replace('"',"").strip()
        years = year.find("a").get_text().strip()
        reparto_festivales_lista.append(f"{festival} @ {categoria} @ {years} @ {reparto} @ {pelicula} @ {director}")

# %% [markdown]
# Recopilo los datos, los almaceno en un diccionario y convierto en dataframe y exporto a csv para poder tener tratar la información después

# %%
dicc_reparto_certamenes["premios_reparto"] = reparto_festivales_lista
df_premios_reparto = pd.DataFrame(dicc_reparto_certamenes)
# df_premios_reparto.to_csv("..\data\raw\repartos_premiados_todos.csv", encoding="utf16")

# %%
len(list_definitive)
# Out:
# 865

# %% [markdown]
# Extraigo el recuento de todas las etiquetas que existen en la web para poder utilizazr esa información en el análisis e información que proporcionaré al algoritmo

# %%
response = requests.get("https://www.filmaffinity.com/es/topics.php")
html = response.content
soup = bs(html, "lxml")

# %%
tags = soup.find_all("a", {"class":"topic"})

tag_lista = []
num_tag = []
dicc_tags = {}

for tag in tags:
    tag_lista.append(tag.get_text().split("(")[0].strip())
    num_tag.append(tag.get_text().split("(")[1].replace(")","").strip())

# %%
len(tag_lista), len(num_tag)
# Out:
# (415, 415)

# %%
import requests

datospelis = []

for i in range(75000,100000):

    url = f"https://api.themoviedb.org/3/movie/{i}?api_key=7b34ecc56572df48f2ce676be26adbeb"
    response = requests.get(url)

    if response.status_code == 200:
        data = response.json()
        datospelis.append({
                        'Titulo': data['title'],
                        'Presupuesto': data['budget']
                        })

    # else:
    #     print("Error al obtener la información de la película con el ID:", i)

# %%
# import pandas as pd

# df_pelis_budget = pd.DataFrame(datospelis)
# df_pelis_budget.to_csv("..\data\fichas_peliculas\budget_004.csv", encoding="utf16")
